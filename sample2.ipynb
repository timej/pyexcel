# %%
import pandas as pd

# %%
df = pd.read_csv('data/sample2_lf.csv', header=None)

# %%
df
# Out:
#    0              1               2
# 0  1         カンマを含む        abc, def
# 1  2          改行を含む    あいうえお\nカキクケコ
# 2  3  ダブルクオテーションを含む  "東京"、"大阪"、"福岡"

# %%
df_crlf = pd.read_csv('data/sample2_crlf.csv', header=None)

# %%
df_crlf
# Out:
#    0              1               2
# 0  1         カンマを含む        abc, def
# 1  2          改行を含む  あいうえお\r\nカキクケコ
# 2  3  ダブルクオテーションを含む  "東京"、"大阪"、"福岡"

# %%
df.to_excel('data/sample2_lf.xlsx', header=False, index=False)
df_crlf.to_excel('data/sample2_crlf.xlsx', header=False, index=False)

# %%
url1 = 'http://www.esri.cao.go.jp/jp/sna/data/data_list/sokuhou/files/2017/qe173_2/__icsFiles/afieldfile/2017/12/07/gaku-mg1732.csv'

# %%
df1 = pd.read_csv(url1, encoding='cp932', header=None)

# %%
df1
# Out:
#                            0                          1                   2   \
# 0                       名目原系列                        NaN                 NaN
# 1    Nominal, Original Series                        NaN                 NaN
# 2                         NaN                 国内総生産(支出側)            民間最終消費支出
# 3                         NaN                        NaN                 NaN
# 4                         NaN                        NaN                 NaN
# 5                         NaN  GDP(Expenditure Approach)  PrivateConsumption
# 6                         NaN                        NaN                 NaN
# 7                 1994/ 1- 3.                 120,796.3            64,829.3
# 8                       4- 6.                 122,571.1            65,713.6
# 9                       7- 9.                 123,429.8            67,995.2
# 10                     10-12.                 134,740.5            69,903.5
# ...

# %%
url2 = 'https://www.e-stat.go.jp/SG1/estat/GL08020103.do?_csvDownload_&fileId=000008040455&releaseCount=3'

# %%
df2 = pd.read_csv(url2, encoding='cp932', header=None, dtype=object)

# %%
df2[df2['地域コード'] == 7543]
# Out:
#           12  ※大項目  地域コード 地域識別コード  境域年次(2015)  境域年次(2000) Unnamed: 6  総数（年齢）  \
# 804      817   101   7543       3      2015.0      2000.0        富岡町     NaN
# 6357    6370   102   7543       3      2015.0      2000.0        富岡町     NaN
# 11910  11923   201   7543       3      2015.0      2000.0        富岡町     NaN
# 17463  17476   202   7543       3      2015.0      2000.0        富岡町     NaN
# 23016  23029   301   7543       3      2015.0      2000.0        富岡町     NaN
# 28569  28582   302   7543       3      2015.0      2000.0        富岡町     NaN
#
#        0歳  1歳         ...          （再掲）15歳未満  （再掲）15～64歳  （再掲）65歳以上  \
# 804   NaN NaN         ...                NaN         NaN        NaN
# 6357  NaN NaN         ...                NaN         NaN        NaN
# 11910 NaN NaN         ...                NaN         NaN        NaN
# 17463 NaN NaN         ...                NaN         NaN        NaN
# 23016 NaN NaN         ...                NaN         NaN        NaN
# ...

# %%
import requests
import io

# %%
url2 = 'https://www.e-stat.go.jp/SG1/estat/GL08020103.do?_csvDownload_&fileId=000008040455&releaseCount=3'
r = requests.get(url2)
r.encoding = 'cp932'

# %%
df2 = pd.read_csv(io.StringIO(r.text), header=None, dtype=object)

# %%
df2
# Out:
#          0                         1      2        3           4    \
# 0          1  平成27年国勢調査人口等基本集計（総務省統計局）    NaN      NaN         NaN
# 1          2                       NaN    NaN      NaN         NaN
# 2          3                       NaN    NaN      NaN         NaN
# 3          4                       NaN    NaN      NaN         NaN
# 4          5                       NaN    NaN      NaN         NaN
# 5          6                       NaN    NaN      NaN         NaN
# 6          7                       NaN    NaN      NaN         NaN
# 7          8                       NaN    NaN      NaN         NaN
# 8          9                       NaN    NaN      NaN         NaN
# 9         10                       NaN    NaN      NaN         NaN
# 10        11                       NaN    NaN      NaN         NaN
# 11        12                      ※大項目  地域コード  地域識別コード  境域年次(2015)
# 12        13                      0101  00000        a        2015
# ...

# %%
df2 = pd.read_csv(io.StringIO(r.text), header=11, na_values='-')

# %%
df2
# Out:
#           12  ※大項目  地域コード 地域識別コード  境域年次(2015)  境域年次(2000)      Unnamed: 6  \
# 0         13   101      0       a      2015.0      2000.0              全国
# 1         14   101      1       b      2015.0      2000.0              市部
# 2         15   101      2       b      2015.0      2000.0              郡部
# 3         16   101   1000       a      2015.0      2000.0             北海道
# 4         17   101   1001       b      2015.0      2000.0              市部
# 5         18   101   1002       b      2015.0      2000.0              郡部
# 6         19   101   1100       1      2015.0      2000.0             札幌市
# 7         20   101   1101       0      2015.0      2000.0         札幌市 中央区
# 8         21   101   1102       0      2015.0      2000.0          札幌市 北区
# 9         22   101   1103       0      2015.0      2000.0          札幌市 東区
# 10        23   101   1104       0      2015.0      2000.0         札幌市 白石区
# 11        24   101   1105       0      2015.0      2000.0         札幌市 豊平区
# ...

# %%
df2 = pd.read_csv(io.StringIO(r.text), header=11, na_values='-', dtype={'地域コード': object})
# Out:
#           12  ※大項目  地域コード 地域識別コード  境域年次(2015)  境域年次(2000)      Unnamed: 6  \
# 0         13   101  00000       a      2015.0      2000.0              全国
# 1         14   101  00001       b      2015.0      2000.0              市部
# 2         15   101  00002       b      2015.0      2000.0              郡部
# 3         16   101  01000       a      2015.0      2000.0             北海道
# 4         17   101  01001       b      2015.0      2000.0              市部
# 5         18   101  01002       b      2015.0      2000.0              郡部
# 6         19   101  01100       1      2015.0      2000.0             札幌市
# 7         20   101  01101       0      2015.0      2000.0         札幌市 中央区
# 8         21   101  01102       0      2015.0      2000.0          札幌市 北区
# 9         22   101  01103       0      2015.0      2000.0          札幌市 東区
# 10        23   101  01104       0      2015.0      2000.0         札幌市 白石区
# 11        24   101  01105       0      2015.0      2000.0         札幌市 豊平区
# ...
