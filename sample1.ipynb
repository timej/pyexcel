# %%
import pandas as pd

# %%
df = pd.read_excel('data/sample1.xlsx')

# %%
df
# Out:
#           注文日   地域  顧客      商品   数量   単価     金額
# 0  2017-11-14   北区  山田  シャープペン   32  110   3520
# 1  2017-11-14  中央区  田中   ボールペン   52   90   4680
# 2  2017-11-14   西区  伊藤     ノート   33  100   3300
# 3  2017-11-14  中央区  鈴木      鉛筆   35  190   6650
# 4  2017-11-14   北区  佐藤   バインダー   28   80   2240
# 5  2017-11-15   西区  伊藤      鉛筆   75  130   9750
# 6  2017-11-15  中央区  田中      封筒   78  160  12480
# 7  2017-11-15   南区  大阪  シャープペン   45  100   4500
# 8  2017-11-16   西区  長崎      封筒    2  100    200
# 9  2017-11-17   東区  福島   バインダー   89   60   5340
# 10 2017-11-17  中央区  田中   ボールペン   52   20   1040
# 11 2017-11-17   西区  伊藤      封筒   22   50   1100
# 12 2017-11-17   北区  佐藤   ボールペン    4  160    640
# 13 2017-11-18   南区  大阪  シャープペン   17   20    340
# 14 2017-11-19   北区  佐藤     ノート   77   40   3080
# 15 2017-11-19   西区  伊藤   ボールペン    5  110    550
# 16 2017-11-19   南区  大阪      鉛筆   94   70   6580
# 17 2017-11-19   東区  香川     ノート   28   70   1960
# 18 2017-11-20  中央区  鈴木   ボールペン   96   80   7680
# ...

# %%
df['顧客'].value_counts()
# Out:
# 佐藤    7
# 鈴木    6
# 伊藤    6
# 大阪    5
# 山田    5
# 田中    4
# 長崎    4
# 福井    3
# 福島    2
# 石川    2
# 香川    2
# 山口    2
# 宮崎    2
# Name: 顧客, dtype: int64

# %%
df['顧客'].value_counts().to_excel('data/sample1_result.xlsx')

# %%
df['顧客'].drop_duplicates()
# Out:
# 0     山田
# 1     田中
# 2     伊藤
# 3     鈴木
# 4     佐藤
# 7     大阪
# 8     長崎
# 9     福島
# 17    香川
# 20    石川
# 25    福井
# 29    山口
# 33    宮崎
# Name: 顧客, dtype: object

# %%
nd = df['顧客'].unique()

# %%
nd
# Out:
# array(['山田', '田中', '伊藤', '鈴木', '佐藤', '大阪', '長崎', '福島', '香川', '石川', '福井',
#        '山口', '宮崎'], dtype=object)

# %%
pd.Series(nd).to_excel('data/sample1_result.xlsx', header=False, index=False)

# %%
pd.Series(nd).to_clipboard()
